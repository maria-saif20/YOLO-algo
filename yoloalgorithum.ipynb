# %% [markdown]
# <a href="https://colab.research.google.com/github/maria-saif20/YOLO-algo/blob/main/yoloalgorithum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import Image

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 710.2/710.2 kB 4.4 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

# %%
import torch

# %%
# !yolo task=detect mode=predict model=yolov8s.pt source='/content/image.jpg'
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 159MB/s]
# Ultralytics YOLOv8.1.13 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s summary (fused): 168 layers, 11156544 parameters, 0 gradients, 28.6 GFLOPs
#
# image 1/1 /content/image.jpg: 448x640 11 persons, 1 bicycle, 1 motorcycle, 1 bus, 2 traffic lights, 3 backpacks, 3 handbags, 83.1ms
# Speed: 13.5ms preprocess, 83.1ms inference, 869.6ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
from ultralytics import YOLO

# %%
#initilazing with model name
model=YOLO("yolov8s.pt")

#predict the result from the model
model.predict(source='/content/image.jpg' , save=True, conf=0.8)
# Out:
# image 1/1 /content/image.jpg: 448x640 5 persons, 1 bus, 1 backpack, 13.7ms
# Speed: 3.0ms preprocess, 13.7ms inference, 1.7ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict3
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
# ...

# %%
# !yolo task=detect mode=predict model=yolov8s.pt source='/content/image.jpg' save_crop=true
# Out:
# Ultralytics YOLOv8.1.13 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s summary (fused): 168 layers, 11156544 parameters, 0 gradients, 28.6 GFLOPs
#
# image 1/1 /content/image.jpg: 448x640 11 persons, 1 bicycle, 1 motorcycle, 1 bus, 2 traffic lights, 3 backpacks, 3 handbags, 99.3ms
# Speed: 3.7ms preprocess, 99.3ms inference, 588.7ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict4
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=predict model=yolov8s.pt source='/content/image.jpg' hide_labels=true hide_conf=true
# Out:
# WARNING ⚠️ 'hide_labels' is deprecated and will be removed in 'ultralytics 8.299999999999999' in the future. Please use 'show_labels' instead.
# WARNING ⚠️ 'hide_conf' is deprecated and will be removed in 'ultralytics 8.299999999999999' in the future. Please use 'show_conf' instead.
# Ultralytics YOLOv8.1.13 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s summary (fused): 168 layers, 11156544 parameters, 0 gradients, 28.6 GFLOPs
#
# image 1/1 /content/image.jpg: 448x640 11 persons, 1 bicycle, 1 motorcycle, 1 bus, 2 traffic lights, 3 backpacks, 3 handbags, 97.1ms
# Speed: 3.7ms preprocess, 97.1ms inference, 657.4ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict6
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# !yolo task=detect mode=predict model=yolov8s.pt source='/content/video1.mp4'
# Out:
# Ultralytics YOLOv8.1.13 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8s summary (fused): 168 layers, 11156544 parameters, 0 gradients, 28.6 GFLOPs
#
# video 1/1 (1/1314) /content/video1.mp4: 384x640 3 cars, 97.5ms
# video 1/1 (2/1314) /content/video1.mp4: 384x640 3 cars, 10.9ms
# video 1/1 (3/1314) /content/video1.mp4: 384x640 3 cars, 10.8ms
# video 1/1 (4/1314) /content/video1.mp4: 384x640 3 cars, 10.8ms
# video 1/1 (5/1314) /content/video1.mp4: 384x640 5 cars, 10.8ms
# video 1/1 (6/1314) /content/video1.mp4: 384x640 4 cars, 10.8ms
# video 1/1 (7/1314) /content/video1.mp4: 384x640 6 cars, 10.8ms
# video 1/1 (8/1314) /content/video1.mp4: 384x640 4 cars, 1 truck, 10.8ms
# video 1/1 (9/1314) /content/video1.mp4: 384x640 4 cars, 1 truck, 10.8ms
# video 1/1 (10/1314) /content/video1.mp4: 384x640 6 cars, 1 truck, 10.8ms
# video 1/1 (11/1314) /content/video1.mp4: 384x640 6 cars, 1 truck, 10.8ms
# ...
